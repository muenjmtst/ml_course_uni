# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

df = pd.read_csv('stud.csv')

# %%
df.head()
# Out:
#    student_id  age  gender education_level school_type family_income  \
# 0  STU_000001   20  Female     High School      Public        Middle
# 1  STU_000002   17    Male     High School      Public        Middle
# 2  STU_000003   18   Other   Undergraduate      Public        Middle
# 3  STU_000004   20    Male     High School      Public        Middle
# 4  STU_000005   16  Female     High School     Private          High
#
#   parent_education urban_rural  previous_exam_score  previous_gpa  ...  \
# 0              NaN       Rural                78.36          2.95  ...
# 1              NaN    Suburban                73.40          2.89  ...
# 2           Master       Urban                82.76          3.35  ...
# 3      High School    Suburban                60.61          2.57  ...
# 4         Bachelor    Suburban                74.79          2.84  ...
#
#    exam_difficulty  exam_preparation_days questions_attempted  \
# ...

# %%
df.tail()
# Out:
#        student_id  age  gender education_level school_type family_income  \
# 99995  STU_099996   17    Male   Undergraduate      Public  Upper-Middle
# 99996  STU_099997   14  Female     High School      Public  Upper-Middle
# 99997  STU_099998   16  Female     High School      Public  Upper-Middle
# 99998  STU_099999   15  Female     High School     Private          High
# 99999  STU_100000   18  Female   Undergraduate     Charter  Lower-Middle
#
#       parent_education urban_rural  previous_exam_score  previous_gpa  ...  \
# 99995              NaN    Suburban                78.73           NaN  ...
# 99996         Bachelor    Suburban                75.70          2.98  ...
# 99997      High School    Suburban                84.69          3.27  ...
# 99998           Master       Rural                74.70          3.06  ...
# 99999              NaN       Urban                76.73          2.97  ...
#
#        exam_difficulty  exam_preparation_days questions_attempted  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 44 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   student_id                  100000 non-null  object
#  1   age                         100000 non-null  int64
#  2   gender                      100000 non-null  object
#  3   education_level             100000 non-null  object
#  4   school_type                 100000 non-null  object
#  5   family_income               100000 non-null  object
#  6   parent_education            93474 non-null   object
#  7   urban_rural                 100000 non-null  object
#  8   previous_exam_score         100000 non-null  float64
#  9   previous_gpa                92207 non-null   float64
#  10  attendance_percentage       90137 non-null   float64
#  11  assignment_completion_rate  100000 non-null  float64
# ...

# %%
df.describe()
# Out:
#                  age  previous_exam_score  previous_gpa  \
# count  100000.000000        100000.000000  92207.000000
# mean       17.005740            69.531033      2.780892
# std         1.999562            11.379108      0.478218
# min        14.000000            30.000000      1.000000
# 25%        15.000000            61.820000      2.460000
# 50%        17.000000            69.530000      2.780000
# 75%        19.000000            77.232500      3.110000
# max        20.000000           100.000000      4.000000
#
#        attendance_percentage  assignment_completion_rate  study_hours_per_day  \
# count           90137.000000               100000.000000        100000.000000
# mean               84.616882                   69.724405             2.995725
# std                 7.922485                   12.127179             1.719466
# min                46.340000                   20.000000             0.500000
# ...

# %%
df.describe(include=["object"])
# Out:
#         student_id  gender education_level school_type family_income  \
# count       100000  100000          100000      100000        100000
# unique      100000       3               2           3             5
# top     STU_000001    Male     High School      Public        Middle
# freq             1   49130           59752       55105         30112
#
#        parent_education urban_rural class_participation study_consistency  \
# count             93474      100000              100000            100000
# unique                5           3                   3                 3
# top         High School       Urban              Medium            Medium
# freq              28122       44963               50109             55137
#
#        study_environment  ... notes_quality sleep_quality break_frequency  \
# count             100000  ...         91593         93006          100000
# unique                 3  ...             3             4               3
# ...

# %%
print(df.shape)
print(df.columns)
print(df.dtypes)
print(df.info())
# Out:
# (100000, 44)
# Index(['student_id', 'age', 'gender', 'education_level', 'school_type',
#        'family_income', 'parent_education', 'urban_rural',
#        'previous_exam_score', 'previous_gpa', 'attendance_percentage',
#        'assignment_completion_rate', 'class_participation',
#        'study_hours_per_day', 'self_study_hours', 'private_tuition',
#        'online_learning_hours', 'study_consistency', 'study_environment',
#        'study_method', 'revision_frequency', 'practice_tests_completed',
#        'notes_quality', 'sleep_hours', 'sleep_quality', 'daily_screen_time',
#        'physical_activity_hours', 'break_frequency', 'stress_level',
#        'motivation_level', 'internet_access', 'device_availability',
#        'educational_app_usage', 'online_course_hours', 'exam_difficulty',
#        'exam_preparation_days', 'questions_attempted', 'questions_correct',
#        'time_management_score', 'exam_anxiety_level', 'exam_score',
# ...

# %%
df.isnull().sum()
# Out:
# student_id                       0
# age                              0
# gender                           0
# education_level                  0
# school_type                      0
# family_income                    0
# parent_education              6526
# urban_rural                      0
# previous_exam_score              0
# previous_gpa                  7793
# attendance_percentage         9863
# assignment_completion_rate       0
# class_participation              0
# study_hours_per_day              0
# self_study_hours                 0
# private_tuition                  0
# online_learning_hours            0
# study_consistency                0
# study_environment                0
# study_method                     0
# revision_frequency               0
# practice_tests_completed         0
# notes_quality                 8407
# sleep_hours                      0
# sleep_quality                 6994
# daily_screen_time                0
# physical_activity_hours          0
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.nunique()
# Out:
# student_id                    100000
# age                                7
# gender                             3
# education_level                    2
# school_type                        3
# family_income                      5
# parent_education                   5
# urban_rural                        3
# previous_exam_score             6153
# previous_gpa                     296
# attendance_percentage           3911
# assignment_completion_rate      6384
# class_participation                3
# study_hours_per_day             1073
# self_study_hours                 856
# private_tuition                    2
# online_learning_hours           1330
# study_consistency                  3
# study_environment                  3
# study_method                       5
# revision_frequency                 3
# practice_tests_completed          21
# notes_quality                      3
# sleep_hours                      793
# sleep_quality                      4
# ...

# %%
df.sort_values("exam_score", ascending=False).head()
# Out:
#        student_id  age  gender education_level school_type family_income  \
# 36973  STU_036974   17   Other     High School      Public        Middle
# 94148  STU_094149   14  Female   Undergraduate     Private  Upper-Middle
# 38742  STU_038743   15    Male     High School      Public  Upper-Middle
# 12636  STU_012637   20  Female     High School     Private        Middle
# 12560  STU_012561   16  Female   Undergraduate     Private  Lower-Middle
#
#       parent_education urban_rural  previous_exam_score  previous_gpa  ...  \
# 36973              NaN    Suburban                90.87          3.83  ...
# 94148         Bachelor    Suburban                83.48          3.23  ...
# 38742         Bachelor       Rural                72.16          2.79  ...
# 12636      High School       Rural                73.43          2.93  ...
# 12560        Associate       Urban                80.77          3.33  ...
#
#        exam_difficulty  exam_preparation_days questions_attempted  \
# ...

# %%
df[df['exam_score']<80].head()
# Out:
#    student_id  age  gender education_level school_type family_income  \
# 2  STU_000003   18   Other   Undergraduate      Public        Middle
# 3  STU_000004   20    Male     High School      Public        Middle
# 4  STU_000005   16  Female     High School     Private          High
# 5  STU_000006   18    Male     High School      Public          High
# 6  STU_000007   18    Male     High School     Charter        Middle
#
#   parent_education urban_rural  previous_exam_score  previous_gpa  ...  \
# 2           Master       Urban                82.76          3.35  ...
# 3      High School    Suburban                60.61          2.57  ...
# 4         Bachelor    Suburban                74.79          2.84  ...
# 5      High School       Rural                67.68           NaN  ...
# 6              NaN       Urban                78.84          3.00  ...
#
#    exam_difficulty  exam_preparation_days questions_attempted  \
# ...

# %%
df[(df['exam_score'] == 80) & (df['previous_gpa'] < 3.8)].head()
# Out:
#        student_id  age  gender education_level school_type family_income  \
# 5281   STU_005282   20  Female     High School     Charter  Lower-Middle
# 20613  STU_020614   14    Male   Undergraduate      Public        Middle
# 46326  STU_046327   19  Female     High School     Private  Lower-Middle
# 58375  STU_058376   19  Female   Undergraduate     Private  Lower-Middle
# 62339  STU_062340   16  Female     High School      Public  Lower-Middle
#
#       parent_education urban_rural  previous_exam_score  previous_gpa  ...  \
# 5281         Doctorate    Suburban                90.75          3.35  ...
# 20613      High School       Rural                60.24          2.40  ...
# 46326        Associate    Suburban                81.62          3.34  ...
# 58375           Master       Rural                65.19          2.54  ...
# 62339        Associate    Suburban                75.78          3.23  ...
#
#        exam_difficulty  exam_preparation_days questions_attempted  \
# ...

# %%
df.groupby("gender")["exam_score"].mean()
# Out:
# gender
# Female    61.946438
# Male      61.961913
# Other     61.750838
# Name: exam_score, dtype: float64

# %%
df.groupby("gender")["exam_score"].agg(["mean", "min", "max", "count"])
# Out:
#              mean    min    max  count
# gender
# Female  61.946438   0.00  100.0  48841
# Male    61.961913   0.00  100.0  49130
# Other   61.750838  10.25  100.0   2029

# %%
corr_matrix = df.corr(numeric_only=True)
corr_matrix['previous_gpa'].sort_values(ascending=False)
# Out:
# previous_gpa                  1.000000
# previous_exam_score           0.949446
# exam_score                    0.467763
# questions_correct             0.455888
# attendance_percentage         0.040821
# assignment_completion_rate    0.017305
# stress_level                  0.004188
# time_management_score         0.003153
# exam_preparation_days         0.002029
# exam_anxiety_level            0.001582
# questions_attempted           0.001434
# sleep_hours                   0.001127
# online_course_hours           0.001034
# internet_access               0.000922
# daily_screen_time             0.000428
# study_hours_per_day           0.000337
# self_study_hours              0.000069
# physical_activity_hours      -0.001540
# private_tuition              -0.001578
# age                          -0.001699
# practice_tests_completed     -0.003116
# online_learning_hours        -0.004246
# Name: previous_gpa, dtype: float64

# %%
from pandas.plotting import scatter_matrix
attributes = ['previous_exam_score', 'exam_score', 'questions_correct', 'attendance_percentage']
scatter_matrix(df[attributes],figsize=(12,8))
# Out:
# array([[<Axes: xlabel='previous_exam_score', ylabel='previous_exam_score'>,
#         <Axes: xlabel='exam_score', ylabel='previous_exam_score'>,
#         <Axes: xlabel='questions_correct', ylabel='previous_exam_score'>,
#         <Axes: xlabel='attendance_percentage', ylabel='previous_exam_score'>],
#        [<Axes: xlabel='previous_exam_score', ylabel='exam_score'>,
#         <Axes: xlabel='exam_score', ylabel='exam_score'>,
#         <Axes: xlabel='questions_correct', ylabel='exam_score'>,
#         <Axes: xlabel='attendance_percentage', ylabel='exam_score'>],
#        [<Axes: xlabel='previous_exam_score', ylabel='questions_correct'>,
#         <Axes: xlabel='exam_score', ylabel='questions_correct'>,
#         <Axes: xlabel='questions_correct', ylabel='questions_correct'>,
#         <Axes: xlabel='attendance_percentage', ylabel='questions_correct'>],
#        [<Axes: xlabel='previous_exam_score', ylabel='attendance_percentage'>,
# ...

# %%
plt.figure(figsize=(8,4))
sns.histplot(df['exam_score'], kde=True, color='skyblue')
# Out:
# <Axes: xlabel='exam_score', ylabel='Count'>

# %%
plt.figure(figsize=(10, 8))
numeric_df = df.select_dtypes(include=[np.number])
sns.heatmap(numeric_df.corr(), cmap='coolwarm', annot=False)
# Out:
# <Axes: >
